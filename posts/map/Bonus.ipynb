# %% [markdown]
# ---
# title: "Bonus: Leafmap Geotif generation"
# author: ["Hrriday Ruparel", "Prathmesh Maharshi"]
# date: "2025-02-24"
# image: "output.png"
# format:
#     html:
#         code-fold: false
#         code-tools: true
# jupyter: python3
# ---

# %%
from leafmap import leafmap

# %%
m = leafmap.Map()
m.add_basemap("Google Hybrid", visible = True)
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
bbox = m.user_roi_bounds()

# %% [markdown]
# Modern web mapping systems like Google Maps, OpenStreetMap, and Esri's platforms use a quadtree tile structure under the Web Mercator projection (EPSG:3857). At zoom level 0, a single 256x256 pixel tile encapsulates the entire Earth's surface (approximately 40,075 km equatorial circumference). Each subsequent zoom level divides parent tiles into four child tiles, creating a grid of $$2^{zoom} \times 2^{zoom}$$ tiles
#
# The ground resolution at any zoom level derives from the formula:
# $$
# \text{Resolution} = \frac{\text{Earth Circumference}\cdot{\cos(\text{Latitude})}}{2^{zoom} \times 256}  \qquad \qquad \qquad [1]
# $$
# For zoom level 19 at equator ($Lat = 0$):
# $$
# \frac{40,075,017\ \text{m}}{2^{19} \times 256} = \frac{40,075,017}{524,288 \times 256} \approx 0.2986\ \text{m/pixel}
# $$
# This produces a per-pixel resolution of approximately **30 centimeters** at the equator.
#
# Geo-tifs were acquired from three loactions:
# - IIT Gandhinagar, India ($Lat \approx 23.2$)<br>
# - IIT Delhi, India ($Lat \approx 28.5$)<br>
# - Honolulu, Hawaii ($Lat \approx 21.3$)
#
# All of these locations can be *approximately* resolved at $0.3m$ spatial resolution using `zoom = 19` as explained above
#
# References:<br>
# [1] https://gis.stackexchange.com/questions/108763/how-to-calculate-pixels-per-meter-ratio-according-to-google-or-bing-map-zoom-le

# %%
def make_square_bbox(bbox):
    """
    Convert a bounding box into a square by adjusting latitude or longitude bounds.
    
    Parameters:
        bbox (list): A list of [minx, miny, maxx, maxy].
    
    Returns:
        list: A square bounding box as [minx, miny, maxx, maxy].
    """
    minx, miny, maxx, maxy = bbox
    
    # Calculate width and height
    width = maxx - minx
    height = maxy - miny
    
    if width > height:
        # Adjust latitude bounds to match width
        delta = (width - height) / 2
        miny -= delta
        maxy += delta
    elif height > width:
        # Adjust longitude bounds to match height
        delta = (height - width) / 2
        minx -= delta
        maxx += delta
    
    # Ensure the bounding box stays valid
    minx = max(minx, -180)
    maxx = min(maxx, 180)
    miny = max(miny, -90)
    maxy = min(maxy, 90)
    
    return [minx, miny, maxx, maxy]

square_bbox = make_square_bbox(bbox)

# %%
leafmap.map_tiles_to_geotiff(
    output="satellite13.tif",
    bbox=square_bbox,
    source="Esri.WorldImagery",
    zoom = 20,  
    crs="EPSG:3857",  # Standard web mercator
    to_cog=False  # Skip converting to Cloud Optimized GeoTIFF if not needed
)
# Out:
# Downloaded image 1/240
# Downloaded image 2/240
# Downloaded image 3/240
# Downloaded image 4/240
# Downloaded image 5/240
# Downloaded image 6/240
# Downloaded image 7/240
# Downloaded image 8/240
# Downloaded image 9/240
# Downloaded image 10/240
# Downloaded image 11/240
# Downloaded image 12/240
# Downloaded image 13/240
# Downloaded image 14/240
# Downloaded image 15/240
# Downloaded image 16/240
# Downloaded image 17/240
# Downloaded image 18/240
# Downloaded image 19/240
# Downloaded image 20/240
# Downloaded image 21/240
# Downloaded image 22/240
# Downloaded image 23/240
# Downloaded image 24/240
# Downloaded image 25/240
# Downloaded image 26/240
# Downloaded image 27/240
# Downloaded image 28/240
# Downloaded image 29/240
# Downloaded image 30/240
# Downloaded image 31/240
# Downloaded image 32/240
# Downloaded image 33/240
# Downloaded image 34/240
# Downloaded image 35/240
# Downloaded image 36/240
# Downloaded image 37/240
# Downloaded image 38/240
# Downloaded image 39/240
# Downloaded image 40/240
# Downloaded image 41/240
# Downloaded image 42/240
# Downloaded image 43/240
# Downloaded image 44/240
# Downloaded image 45/240
# Downloaded image 46/240
# Downloaded image 47/240
# Downloaded image 48/240
# Downloaded image 49/240
# Downloaded image 50/240
# Downloaded image 51/240
# Downloaded image 52/240
# Downloaded image 53/240
# Downloaded image 54/240
# Downloaded image 55/240
# Downloaded image 56/240
# Downloaded image 57/240
# Downloaded image 58/240
# Downloaded image 59/240
# Downloaded image 60/240
# Downloaded image 61/240
# Downloaded image 62/240
# Downloaded image 63/240
# Downloaded image 64/240
# Downloaded image 65/240
# Downloaded image 66/240
# Downloaded image 67/240
# Downloaded image 68/240
# Downloaded image 69/240
# Downloaded image 70/240
# Downloaded image 71/240
# Downloaded image 72/240
# Downloaded image 73/240
# Downloaded image 74/240
# Downloaded image 75/240
# Downloaded image 76/240
# Downloaded image 77/240
# Downloaded image 78/240
# Downloaded image 79/240
# Downloaded image 80/240
# Downloaded image 81/240
# Downloaded image 82/240
# Downloaded image 83/240
# Downloaded image 84/240
# Downloaded image 85/240
# Downloaded image 86/240
# Downloaded image 87/240
# Downloaded image 88/240
# Downloaded image 89/240
# Downloaded image 90/240
# Downloaded image 91/240
# Downloaded image 92/240
# Downloaded image 93/240
# Downloaded image 94/240
# Downloaded image 95/240
# Downloaded image 96/240
# Downloaded image 97/240
# Downloaded image 98/240
# Downloaded image 99/240
# Downloaded image 100/240
# Downloaded image 101/240
# Downloaded image 102/240
# Downloaded image 103/240
# Downloaded image 104/240
# Downloaded image 105/240
# Downloaded image 106/240
# Downloaded image 107/240
# Downloaded image 108/240
# Downloaded image 109/240
# Downloaded image 110/240
# Downloaded image 111/240
# Downloaded image 112/240
# Downloaded image 113/240
# Downloaded image 114/240
# Downloaded image 115/240
# Downloaded image 116/240
# Downloaded image 117/240
# Downloaded image 118/240
# Downloaded image 119/240
# Downloaded image 120/240
# Downloaded image 121/240
# Downloaded image 122/240
# Downloaded image 123/240
# Downloaded image 124/240
# Downloaded image 125/240
# Downloaded image 126/240
# Downloaded image 127/240
# Downloaded image 128/240
# Downloaded image 129/240
# Downloaded image 130/240
# Downloaded image 131/240
# Downloaded image 132/240
# Downloaded image 133/240
# Downloaded image 134/240
# Downloaded image 135/240
# Downloaded image 136/240
# Downloaded image 137/240
# Downloaded image 138/240
# Downloaded image 139/240
# Downloaded image 140/240
# Downloaded image 141/240
# Downloaded image 142/240
# Downloaded image 143/240
# Downloaded image 144/240
# Downloaded image 145/240
# Downloaded image 146/240
# Downloaded image 147/240
# Downloaded image 148/240
# Downloaded image 149/240
# Downloaded image 150/240
# Downloaded image 151/240
# Downloaded image 152/240
# Downloaded image 153/240
# Downloaded image 154/240
# Downloaded image 155/240
# Downloaded image 156/240
# Downloaded image 157/240
# Downloaded image 158/240
# Downloaded image 159/240
# Downloaded image 160/240
# Downloaded image 161/240
# Downloaded image 162/240
# Downloaded image 163/240
# Downloaded image 164/240
# Downloaded image 165/240
# Downloaded image 166/240
# Downloaded image 167/240
# Downloaded image 168/240
# Downloaded image 169/240
# Downloaded image 170/240
# Downloaded image 171/240
# Downloaded image 172/240
# Downloaded image 173/240
# Downloaded image 174/240
# Downloaded image 175/240
# Downloaded image 176/240
# Downloaded image 177/240
# Downloaded image 178/240
# Downloaded image 179/240
# Downloaded image 180/240
# Downloaded image 181/240
# Downloaded image 182/240
# Downloaded image 183/240
# Downloaded image 184/240
# Downloaded image 185/240
# Downloaded image 186/240
# Downloaded image 187/240
# Downloaded image 188/240
# Downloaded image 189/240
# Downloaded image 190/240
# Downloaded image 191/240
# Downloaded image 192/240
# Downloaded image 193/240
# Downloaded image 194/240
# Downloaded image 195/240
# Downloaded image 196/240
# Downloaded image 197/240
# Downloaded image 198/240
# Downloaded image 199/240
# Downloaded image 200/240
# Downloaded image 201/240
# Downloaded image 202/240
# Downloaded image 203/240
# Downloaded image 204/240
# Downloaded image 205/240
# Downloaded image 206/240
# Downloaded image 207/240
# Downloaded image 208/240
# Downloaded image 209/240
# Downloaded image 210/240
# Downloaded image 211/240
# Downloaded image 212/240
# Downloaded image 213/240
# Downloaded image 214/240
# Downloaded image 215/240
# Downloaded image 216/240
# Downloaded image 217/240
# Downloaded image 218/240
# Downloaded image 219/240
# Downloaded image 220/240
# Downloaded image 221/240
# Downloaded image 222/240
# Downloaded image 223/240
# Downloaded image 224/240
# Downloaded image 225/240
# Downloaded image 226/240
# Downloaded image 227/240
# Downloaded image 228/240
# Downloaded image 229/240
# Downloaded image 230/240
# Downloaded image 231/240
# Downloaded image 232/240
# Downloaded image 233/240
# Downloaded image 234/240
# Downloaded image 235/240
# Downloaded image 236/240
# Downloaded image 237/240
# Downloaded image 238/240
# Downloaded image 239/240
# Downloaded image 240/240
# Saving GeoTIFF. Please wait...
# Image saved to satellite13.tif
